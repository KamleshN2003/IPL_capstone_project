# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
df=pd.read_csv("IPL.csv")
df.head(10)
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# 5         6  March 30,2022            Dr DY Patil Sports Academy, Mumbai
# 6         7  March 31,2022                     Brabourne Stadium, Mumbai
# 7         8   April 1,2022                      Wankhede Stadium, Mumbai
# 8         9   April 2,2022            Dr DY Patil Sports Academy, Mumbai
# 9        10   April 2,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
# 5   Banglore    Kolkata  Group    Banglore         Field               128
# 6    Chennai    Lucknow  Group     Lucknow         Field               210
# 7    Kolkata     Punjab  Group     Kolkata         Field               137
# 8     Mumbai  Rajasthan  Group      Mumbai         Field               193
# 9      Delhi    Gujarat  Group       Delhi         Field               171
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
# 5               10                132                 7     Banglore  Wickets
# 6                7                211                 4      Lucknow  Wickets
# 7               10                141                 4      Kolkata  Wickets
# 8                8                170                 8    Rajasthan     Runs
# 9                6                157                 9      Gujarat     Runs
#
#    margin player_of_the_match           top_scorer  highscore  \
# 0       6         Umesh Yadav             MS Dhoni         50
# 1       4       Kuldeep Yadav         Ishan Kishan         81
# 2       5         Odean Smith       Faf du Plessis         88
# 3       5      Mohammed Shami         Deepak Hooda         55
# 4      61        Sanju Samson        Aiden Markram         57
# 5       3   Wanindu Hasaranga  Sherfane Rutherford         28
# 6       6          Evin Lewis      Quinton de Kock         61
# 7       6         Umesh Yadav        Andre Russell         70
# 8      23         Jos Buttler          Jos Buttler        100
# 9      14     Lockie Ferguson         Shubman Gill         84
#
#         best_bowling best_bowling_figure
# 0       Dwayne Bravo               3--20
# 1      Kuldeep Yadav               3--18
# 2     Mohammed Siraj               2--59
# 3     Mohammed Shami               3--25
# 4   Yuzvendra Chahal               3--22
# 5  Wanindu Hasaranga               4--20
# 6       Ravi Bishnoi               2--24
# 7        Umesh Yadav               4--23
# 8     Jasprit Bumrah               3--17
# 9    Lockie Ferguson               4--28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
#  15  player_of_the_match  74 non-null     object
#  16  top_scorer           74 non-null     object
#  17  highscore            74 non-null     int64
#  18  best_bowling         74 non-null     object
#  19  best_bowling_figure  74 non-null     object
# dtypes: int64(7), object(13)
# memory usage: 11.7+ KB

# %%
df.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# 50%            6.000000   8.000000   68.000000
# 75%            8.000000  18.000000   87.750000
# max           10.000000  91.000000  140.000000

# %%
df.shape[0]
# Out:
# 74

# %%
print(f"your rows are {df.shape[0]} and your columns are {df.shape[1]}")
# Out:
# your rows are 74 and your columns are 20

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
match_wins=df['match_winner'].value_counts()
match_wins
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Delhi         7
# Punjab        7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
#
#    margin player_of_the_match      top_scorer  highscore      best_bowling  \
# 0       6         Umesh Yadav        MS Dhoni         50      Dwayne Bravo
# 1       4       Kuldeep Yadav    Ishan Kishan         81     Kuldeep Yadav
# 2       5         Odean Smith  Faf du Plessis         88    Mohammed Siraj
# 3       5      Mohammed Shami    Deepak Hooda         55    Mohammed Shami
# 4      61        Sanju Samson   Aiden Markram         57  Yuzvendra Chahal
#
#   best_bowling_figure
# 0               3--20
# 1               3--18
# 2               2--59
# 3               3--25
# 4               3--22

# %%
#barplot
match_wins=df['match_winner'].value_counts()
sns.barplot(y=match_wins.index, x=match_wins.values,palette='pink')
plt.show()

# %%
sns.countplot(x=df["toss_decision"],palette="rainbow")
plt.title="Toss decision"
plt.show()

# %%
count=df[df['toss_winner']== df["match_winner"]]["match_id"].count()
percentage=(count*100)/df.shape[0]
print(percentage.round(2))
# Out:
# 48.65

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
#
#    margin player_of_the_match      top_scorer  highscore      best_bowling  \
# 0       6         Umesh Yadav        MS Dhoni         50      Dwayne Bravo
# 1       4       Kuldeep Yadav    Ishan Kishan         81     Kuldeep Yadav
# 2       5         Odean Smith  Faf du Plessis         88    Mohammed Siraj
# 3       5      Mohammed Shami    Deepak Hooda         55    Mohammed Shami
# 4      61        Sanju Samson   Aiden Markram         57  Yuzvendra Chahal
#
#   best_bowling_figure
# 0               3--20
# 1               3--18
# 2               2--59
# 3               3--25
# 4               3--22

# %%
sns.countplot(x=df["won_by"])
# plt.show()
print(type(plt.title))
plt.title("won_teams")
# Out:
# <class 'function'>
# Text(0.5, 1.0, 'won_teams')

# %%
import importlib
import matplotlib.pyplot as plt

importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\KIIT\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
print(type(plt))
print(type(plt.title))
# Out:
# <class 'module'>
# <class 'function'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(x=df["won_by"])
plt.title("Won By Teams")
plt.show()

# %%
count=df.head()

# %%
count
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
#
#    margin player_of_the_match      top_scorer  highscore      best_bowling  \
# 0       6         Umesh Yadav        MS Dhoni         50      Dwayne Bravo
# 1       4       Kuldeep Yadav    Ishan Kishan         81     Kuldeep Yadav
# 2       5         Odean Smith  Faf du Plessis         88    Mohammed Siraj
# 3       5      Mohammed Shami    Deepak Hooda         55    Mohammed Shami
# 4      61        Sanju Samson   Aiden Markram         57  Yuzvendra Chahal
#
#   best_bowling_figure
# 0               3--20
# 1               3--18
# 2               2--59
# 3               3--25
# 4               3--22

# %%
count=df["player_of_the_match"].value_counts().head()
count
# Out:
# player_of_the_match
# Kuldeep Yadav      4
# Jos Buttler        3
# Umesh Yadav        2
# Quinton de Kock    2
# David Miller       2
# Name: count, dtype: int64

# %%
sns.barplot(y=count.index,x=count.values)
plt.show()

# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in C:\Users\KIIT\anaconda3\Lib\site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (7.4.5)
# Requirement already satisfied: tornado in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_contrib_nbextensions) (6.4.2)
# Requirement already satisfied: traitlets>=4.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Requirement already satisfied: setuptools in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (80.9.0)
# Requirement already satisfied: jupyter-server in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.16.0)
# Requirement already satisfied: pyyaml in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: packaging in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.1)
# Requirement already satisfied: webencodings in C:\Users\KIIT\anaconda3\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.3.7)
# Requirement already satisfied: pywin32>=300 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (310)
# Requirement already satisfied: jupyter-client>=6.1.12 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (26.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.25.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.28.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.28.0)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in C:\Users\KIIT\anaconda3\Lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.4.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.5)
# Requirement already satisfied: certifi in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.0.9)
# Requirement already satisfied: idna in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.12.1)
# Requirement already satisfied: requests>=2.31 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\KIIT\anaconda3\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (9.0.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.7)
# Requirement already satisfied: nest-asyncio in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (7.0.0)
# Requirement already satisfied: colorama in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Requirement already satisfied: decorator in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.50)
# Requirement already satisfied: stack_data in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: rfc3339-validator in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.10.0)
# Requirement already satisfied: six>=1.5 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\KIIT\anaconda3\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.23)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\KIIT\anaconda3\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: pure-eval in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in C:\Users\KIIT\anaconda3\Lib\site-packages (0.7.0)
# Requirement already satisfied: ipython_genutils in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter_core in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (7.4.5)
# Requirement already satisfied: tornado in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_contrib_nbextensions) (6.4.2)
# Requirement already satisfied: traitlets>=4.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_nbextensions) (5.3.0)
# Requirement already satisfied: setuptools in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (80.9.0)
# Requirement already satisfied: jupyter-server in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.16.0)
# Requirement already satisfied: pyyaml in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: packaging in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (24.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.1)
# Requirement already satisfied: webencodings in C:\Users\KIIT\anaconda3\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.3.7)
# Requirement already satisfied: pywin32>=300 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter_core->jupyter_contrib_nbextensions) (310)
# Requirement already satisfied: jupyter-client>=6.1.12 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (8.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (26.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in C:\Users\KIIT\anaconda3\Lib\site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.25.0)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.28.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.28.0)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in C:\Users\KIIT\anaconda3\Lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.4.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.5)
# Requirement already satisfied: certifi in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.0.9)
# Requirement already satisfied: idna in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\KIIT\anaconda3\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.12.1)
# Requirement already satisfied: requests>=2.31 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\KIIT\anaconda3\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (9.0.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.7)
# Requirement already satisfied: nest-asyncio in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (7.0.0)
# Requirement already satisfied: colorama in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.4.6)
# Requirement already satisfied: decorator in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.50)
# Requirement already satisfied: stack_data in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.2.1)
# Requirement already satisfied: rfc3339-validator in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.10.0)
# Requirement already satisfied: six>=1.5 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in C:\Users\KIIT\anaconda3\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\KIIT\anaconda3\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.23)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\KIIT\anaconda3\Lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\KIIT\anaconda3\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\KIIT\anaconda3\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: pure-eval in C:\Users\KIIT\AppData\Roaming\Python\Python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
high_score=df.groupby("top_scorer")['highscore'].sum().sort_values(ascending=False).head(2)
high_score
# Out:
# top_scorer
# Jos Buttler        651
# Quinton de Kock    377
# Name: highscore, dtype: int64

# %%
high_score.plot(kind="barh")
# Out:
# <Axes: ylabel='top_scorer'>

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# 2                2                208                 5       Punjab  Wickets
# 3                6                161                 5      Gujarat  Wickets
# 4                6                149                 7    Rajasthan     Runs
#
#    margin player_of_the_match      top_scorer  highscore      best_bowling  \
# 0       6         Umesh Yadav        MS Dhoni         50      Dwayne Bravo
# 1       4       Kuldeep Yadav    Ishan Kishan         81     Kuldeep Yadav
# 2       5         Odean Smith  Faf du Plessis         88    Mohammed Siraj
# 3       5      Mohammed Shami    Deepak Hooda         55    Mohammed Shami
# 4      61        Sanju Samson   Aiden Markram         57  Yuzvendra Chahal
#
#   best_bowling_figure
# 0               3--20
# 1               3--18
# 2               2--59
# 3               3--25
# 4               3--22

# %%
df['highest_wickets'] = df['best_bowling_figure'].apply(lambda x :x.split('--')[0])
df['highest_wickets'] = df['highest_wickets'].astype(int)
top_bowlers = df.groupby('best_bowling')['highest_wickets'].sum().sort_values(ascending=False).head(10)
top_bowlers.plot(kind = 'barh')
# Out:
# <Axes: ylabel='best_bowling'>

# %%
venue_count = df['venue'].value_counts()
venue_count
# Out:
# venue
# Wankhede Stadium, Mumbai                        21
# Dr DY Patil Sports Academy, Mumbai              20
# Brabourne Stadium, Mumbai                       16
# Maharashtra Cricket Association Stadium,Pune    13
# Eden Gardens, Kolkata                            2
# Narendra Modi Stadium, Ahmedabad                 2
# Name: count, dtype: int64

# %%
sns.barplot(y=venue_count.index,x=venue_count.values)
# Out:
# <Axes: ylabel='venue'>

# %%
df[df['won_by'] == 'Runs'].sort_values(by = 'margin',ascending=False).head(1)[['match_winner','margin']]
# Out:
#    match_winner  margin
# 54      Chennai      91

# %%
df[df['highscore'] == df['highscore'].max()][['top_scorer','highscore']]
# Out:
#          top_scorer  highscore
# 65  Quinton de Kock        140

# %%
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
#    first_ings_wkts  ...  second_ings_wkts  match_winner   won_by margin  \
# 0                5  ...                 4       Kolkata  Wickets      6
# 1                5  ...                 6         Delhi  Wickets      4
# 2                2  ...                 5        Punjab  Wickets      5
# 3                6  ...                 5       Gujarat  Wickets      5
# 4                6  ...                 7     Rajasthan     Runs     61
#
#    player_of_the_match      top_scorer highscore      best_bowling  \
# 0          Umesh Yadav        MS Dhoni        50      Dwayne Bravo
# 1        Kuldeep Yadav    Ishan Kishan        81     Kuldeep Yadav
# 2          Odean Smith  Faf du Plessis        88    Mohammed Siraj
# 3       Mohammed Shami    Deepak Hooda        55    Mohammed Shami
# 4         Sanju Samson   Aiden Markram        57  Yuzvendra Chahal
#
#   best_bowling_figure highest_wickets
# 0               3--20               3
# 1               3--18               3
# 2               2--59               2
# 3               3--25               3
# 4               3--22               3
#
# [5 rows x 21 columns]

# %%
df[df['highest_wickets'] == df['highest_wickets'].max()][['best_bowling','best_bowling_figure']]
# Out:
#          best_bowling best_bowling_figure
# 29   Yuzvendra Chahal               5--40
# 39        Umran Malik               5--25
# 53  Wanindu Hasaranga               5--18
# 55     Jasprit Bumrah               5--10
